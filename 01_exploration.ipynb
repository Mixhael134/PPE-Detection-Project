# %% [markdown]
# <a href="https://colab.research.google.com/github/Mixhael134/PPE-Detection-Project/blob/main/01_exploration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 60.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/drive/MyDrive/CompVis_Data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: CompVis_Data/meta-data/pexels-photo-7643756.json
#   inflating: __MACOSX/CompVis_Data/meta-data/._pexels-photo-7643756.json
#   inflating: CompVis_Data/meta-data/pexels-photo-6045370.json
#   inflating: __MACOSX/CompVis_Data/meta-data/._pexels-photo-6045370.json
#   inflating: CompVis_Data/meta-data/pexels-photo-6684770.json
#   inflating: __MACOSX/CompVis_Data/meta-data/._pexels-photo-6684770.json
#   inflating: CompVis_Data/meta-data/pexels-photo-7674976.json
#   inflating: __MACOSX/CompVis_Data/meta-data/._pexels-photo-7674976.json
#   inflating: CompVis_Data/meta-data/pexels-photo-7640480.json
#   inflating: __MACOSX/CompVis_Data/meta-data/._pexels-photo-7640480.json
#   inflating: CompVis_Data/meta-data/pexels-photo-12057364.json
#   inflating: __MACOSX/CompVis_Data/meta-data/._pexels-photo-12057364.json
#   inflating: CompVis_Data/meta-data/pexels-photo-6931346.json
# ...

# %%
# !ls CompVis_Data
# Out:
# images	labels	meta-data  train_files.txt  val_files.txt  voc_labels

# %%
# !ls CompVis_Data/images
# Out:
# building-construction-building-site-constructing.jpg
# career-firefighter-relaxing-job-162540.jpeg
# carrying-head-indian-farm-worker-158011.jpeg
# construction-site-build-construction-work-159306.jpeg
# construction-site-build-construction-work-159358.jpeg
# construction-site-build-construction-work-159375.jpeg
# floor-flooring-hand-man-1388944.jpeg
# gardener-worker-gardening-machinery-162564.jpeg
# grinder-hitachi-power-tool-flexible-162625.jpeg
# harvest-grain-combine-arable-farming-163752.jpeg
# pexels-photo-10039979.jpeg
# pexels-photo-10039988.jpeg
# pexels-photo-10039989.jpeg
# pexels-photo-10039997.jpeg
# pexels-photo-10040003.jpeg
# pexels-photo-10040011.jpeg
# pexels-photo-10040012.jpeg
# pexels-photo-10045513.jpeg
# pexels-photo-10084716.jpeg
# pexels-photo-10088317.jpeg
# pexels-photo-10101932.jpeg
# pexels-photo-10110710.jpeg
# pexels-photo-10110711.jpeg
# pexels-photo-10119483.jpeg
# pexels-photo-10130751.jpeg
# pexels-photo-10130754.jpeg
# pexels-photo-10133578.jpeg
# ...

# %%
import cv2
import matplotlib.pyplot as plt

image_path = "CompVis_Data/images/pexels-photo-10039979.jpeg"
image = cv2.imread(image_path)

if image is None:
    print(f"Error: Unable to load image from {image_path}. Please check the path and file existence.")
else:
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis("off")
